# %% [markdown]
# <a href="https://colab.research.google.com/github/RebeccaKessler/Otter_Group_Project/blob/main/SeasonalPrecipitationCleaning_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import os
import re
import plotly.express as px
import csv
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings
import statsmodels.api as sm
warnings.filterwarnings("ignore")

# %%
df_prec = pd.read_csv("MonthlyPrecipitation_raw.csv")

# %%
df_prec
# Out:
#            Year         Area   Value
# 0       1901-01  Afghanistan   48.21
# 1       1901-02  Afghanistan   31.63
# 2       1901-03  Afghanistan   52.23
# 3       1901-04  Afghanistan   34.86
# 4       1901-05  Afghanistan   53.82
# ...         ...          ...     ...
# 349891  2022-08     Zimbabwe    1.70
# 349892  2022-09     Zimbabwe    6.60
# 349893  2022-10     Zimbabwe   25.42
# 349894  2022-11     Zimbabwe   75.49
# 349895  2022-12     Zimbabwe  147.85
#
# [349896 rows x 3 columns]

# %%
df_prec[['Year', 'Month']] = df_prec['Year'].str.split('-', expand=True)
df_prec
# Out:
#         Year         Area   Value Month
# 0       1901  Afghanistan   48.21    01
# 1       1901  Afghanistan   31.63    02
# 2       1901  Afghanistan   52.23    03
# 3       1901  Afghanistan   34.86    04
# 4       1901  Afghanistan   53.82    05
# ...      ...          ...     ...   ...
# 349891  2022     Zimbabwe    1.70    08
# 349892  2022     Zimbabwe    6.60    09
# 349893  2022     Zimbabwe   25.42    10
# 349894  2022     Zimbabwe   75.49    11
# 349895  2022     Zimbabwe  147.85    12
#
# [349896 rows x 4 columns]

# %%
df_prec['Year'] = df_prec['Year'].astype(int)
df_prec['Month'] = df_prec['Month'].astype(int)
df_prec
# Out:
#         Year         Area   Value  Month
# 0       1901  Afghanistan   48.21      1
# 1       1901  Afghanistan   31.63      2
# 2       1901  Afghanistan   52.23      3
# 3       1901  Afghanistan   34.86      4
# 4       1901  Afghanistan   53.82      5
# ...      ...          ...     ...    ...
# 349891  2022     Zimbabwe    1.70      8
# 349892  2022     Zimbabwe    6.60      9
# 349893  2022     Zimbabwe   25.42     10
# 349894  2022     Zimbabwe   75.49     11
# 349895  2022     Zimbabwe  147.85     12
#
# [349896 rows x 4 columns]

# %%
df_prec = df_prec.loc[df_prec.Year >= 1961]
df_prec
# Out:
#         Year         Area   Value  Month
# 720     1961  Afghanistan   46.53      1
# 721     1961  Afghanistan   40.28      2
# 722     1961  Afghanistan   67.67      3
# 723     1961  Afghanistan   81.71      4
# 724     1961  Afghanistan   24.92      5
# ...      ...          ...     ...    ...
# 349891  2022     Zimbabwe    1.70      8
# 349892  2022     Zimbabwe    6.60      9
# 349893  2022     Zimbabwe   25.42     10
# 349894  2022     Zimbabwe   75.49     11
# 349895  2022     Zimbabwe  147.85     12
#
# [177816 rows x 4 columns]

# %%
Country_list = ['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
       'Australia', 'Austria', 'Bangladesh', 'Belgium-Luxembourg',
       'Bhutan', 'Bolivia (Plurinational State of)', 'Brazil', 'Bulgaria',
       'Cameroon', 'Canada', 'Chad', 'Chile', 'China', 'Colombia', 'Cuba',
       'Cyprus', 'Czechoslovakia',
       "Democratic People's Republic of Korea",
       'Democratic Republic of the Congo', 'Denmark',
       'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
       'Ethiopia PDR', 'Faroe Islands', 'Fiji', 'Finland', 'France',
       'French Polynesia', 'Germany', 'Greece', 'Guatemala', 'Haiti',
       'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia',
       'Iran (Islamic Republic of)', 'Iraq', 'Ireland', 'Israel', 'Italy',
       'Japan', 'Jordan', 'Kenya', "Lao People's Democratic Republic",
       'Lebanon', 'Lesotho', 'Libya', 'Malta', 'Mauritania', 'Mauritius',
       'Mexico', 'Mongolia', 'Morocco', 'Mozambique', 'Myanmar', 'Nepal',
       'Netherlands (Kingdom of the)', 'New Caledonia', 'New Zealand',
       'Nicaragua', 'Nigeria', 'Norway', 'Pakistan', 'Paraguay', 'Peru',
       'Philippines', 'Poland', 'Portugal', 'Republic of Korea',
       'Romania', 'Saudi Arabia', 'Senegal', 'South Africa', 'Spain',
       'Sri Lanka', 'Sweden', 'Switzerland', 'Syrian Arab Republic',
       'Thailand', 'Tunisia', 'Turkey', 'USSR', 'Uganda',
       'United Kingdom of Great Britain and Northern Ireland',
       'United Republic of Tanzania', 'United States of America',
       'Uruguay', 'Venezuela (Bolivarian Republic of)', 'Viet Nam',
       'Yugoslav SFR', 'Zimbabwe']

# %%
for c in list(df_prec.Area.unique()):
  if c in Country_list:
    print(c)
# Out:
# Afghanistan
# Albania
# Algeria
# Angola
# Argentina
# Australia
# Austria
# Bangladesh
# Bhutan
# Brazil
# Bulgaria
# Cameroon
# Canada
# Chad
# Chile
# China
# Colombia
# Cuba
# Cyprus
# Denmark
# Dominican Republic
# Ecuador
# El Salvador
# Fiji
# Finland
# France
# Germany
# Greece
# Guatemala
# Haiti
# Honduras
# Hungary
# Iceland
# India
# Indonesia
# Iraq
# Ireland
# Israel
# Italy
# Japan
# Jordan
# Kenya
# Lao People's Democratic Republic
# Lebanon
# Lesotho
# Libya
# Malta
# Mauritania
# Mauritius
# Mexico
# Mongolia
# Morocco
# Mozambique
# Myanmar
# Nepal
# New Zealand
# Nicaragua
# Nigeria
# Pakistan
# Paraguay
# Peru
# Philippines
# Poland
# Portugal
# Republic of Korea
# Romania
# Saudi Arabia
# Senegal
# South Africa
# Spain
# Sri Lanka
# Sweden
# Syrian Arab Republic
# Thailand
# Tunisia
# Uganda
# United States of America
# Uruguay
# Zimbabwe

# %%
for c in list(df_prec.Area.unique()):
  if c not in Country_list:
    print(c)
# Out:
# American Samoa (U.S.)
# Andorra
# Anguilla (U.K.)
# Antigua and Barbuda
# Arab Republic of Egypt
# Armenia
# Aruba (Neth.)
# Azerbaijan
# Bahrain
# Barbados
# Belarus
# Belgium
# Belize
# Benin
# Bermuda (U.K.)
# Bolivia
# Bonaire, Sint Eustatius and Saba
# Bosnia and Herzegovina
# Botswana
# Bouvet Island (Nor.)
# British Indian Ocean Territory (U.K.)
# British Virgin Islands (U.K.)
# Brunei Darussalam
# Burkina Faso
# Burundi
# Cabo Verde
# Cambodia
# Cayman Islands (U.K.)
# Central African Republic
# Christmas Island (Aus.)
# Cocos (Keeling) Islands (Aus.)
# Comoros
# Congo
# Cook Islands (N.Z.)
# Costa Rica
# Croatia
# Curaçao (Neth.)
# Czech Republic
# Côte d'Ivoire
# D. P. R. of Korea
# Democratic Republic of Congo
# Djibouti
# Dominica
# Equatorial Guinea
# Eritrea
# Estonia
# Eswatini
# Ethiopia
# Faroe Islands (Den.)
# Federated States of Micronesia
# French Polynesia (Fr.)
# French Southern and Antarctic Lands (Fr.)
# Gabon
# Georgia
# Ghana
# Gibraltar (U.K.)
# ...

# %%
df_prec['Area'] = df_prec['Area'].str.replace('Türkiye', 'Turkey')
df_prec['Area'] = df_prec['Area'].str.replace('Norway\)', 'Norway')
df_prec['Area'] = df_prec['Area'].str.replace('Switzerlandn', 'Switzerland')
df_prec['Area'] = df_prec['Area'].str.replace('Bolivia', 'Bolivia (Plurinational State of)')
df_prec['Area'] = df_prec['Area'].str.replace('D. P. R. of Korea', "Democratic People's Republic of Korea")
df_prec['Area'] = df_prec['Area'].str.replace('Democratic Republic of Congo', 'Democratic Republic of the Congo')
df_prec['Area'] = df_prec['Area'].str.replace('Arab Republic of Egypt', 'Egypt')
df_prec['Area'] = df_prec['Area'].str.replace('Faroe Islands \(Den.\)', 'Faroe Islands')
df_prec['Area'] = df_prec['Area'].str.replace('French Polynesia \(Fr.\)', 'French Polynesia')
df_prec['Area'] = df_prec['Area'].str.replace('Islamic Republic of Iran', "Iran (Islamic Republic of)")
df_prec['Area'] = df_prec['Area'].str.replace('Netherlands', 'Netherlands (Kingdom of the)')
df_prec['Area'] = df_prec['Area'].str.replace('New Caledonia \(Fr.\)', 'New Caledonia')
df_prec['Area'] = df_prec['Area'].str.replace('United Kingdom', "United Kingdom of Great Britain and Northern Ireland")
df_prec['Area'] = df_prec['Area'].str.replace('Tanzania', 'United Republic of Tanzania')
df_prec['Area'] = df_prec['Area'].str.replace('R. B. de Venezuela', 'Venezuela (Bolivarian Republic of)')
df_prec['Area'] = df_prec['Area'].str.replace('Vietnam', 'Viet Nam')

df_prec['Area'] = df_prec['Area'].str.replace('Kyrgyz Republic', "Kyrgyzstan")
df_prec['Area'] = df_prec['Area'].str.replace('Moldova', 'Republic of Moldova')
df_prec['Area'] = df_prec['Area'].str.replace('Turkmenistano', 'Turkmenistan')

df_prec['Area'] = df_prec['Area'].str.replace('Czech Republic', 'Czechia')
df_prec['Area'] = df_prec['Area'].str.replace('Slovak Republic', 'Slovakia')

# %%
SM = ["Serbia","Montenegro"]
USSR = ['Armenia','Azerbaijan','Belarus','Estonia','Georgia','Kazakhstan','Kyrgyzstan'
,'Latvia','Lithuania','Republic of Moldova','Russian Federation','Tajikistan','Turkmenistan',
'Ukraine','Uzbekistan']
Yugo = ['Bosnia and Herzegovina','Croatia','North Macedonia','Serbia and Montenegro','Slovenia']
Czechoslovakia = ['Czechia','Slovakia']
BL = ["Belgium","Luxembourg"]
Ethiopia = ["Ethiopia","Eritrea"]

# %%
df_prec.loc[df_prec.Area == "Faroe Islands"]
# Out:
#         Year           Area   Value  Month
# 104664  1961  Faroe Islands  119.76      1
# 104665  1961  Faroe Islands  151.42      2
# 104666  1961  Faroe Islands  185.05      3
# 104667  1961  Faroe Islands   94.84      4
# 104668  1961  Faroe Islands   40.83      5
# ...      ...            ...     ...    ...
# 105403  2022  Faroe Islands   99.40      8
# 105404  2022  Faroe Islands  146.10      9
# 105405  2022  Faroe Islands  189.71     10
# 105406  2022  Faroe Islands  164.27     11
# 105407  2022  Faroe Islands  177.31     12
#
# [744 rows x 4 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df_prec_Jan = df_prec.loc[df_prec.Month == 1]
df_prec_Feb = df_prec.loc[df_prec.Month == 2]
df_prec_Mar = df_prec.loc[df_prec.Month == 3]
df_prec_Apr = df_prec.loc[df_prec.Month == 4]
df_prec_May = df_prec.loc[df_prec.Month == 5]
df_prec_Jun = df_prec.loc[df_prec.Month == 6]
df_prec_Jul = df_prec.loc[df_prec.Month == 7]
df_prec_Aug = df_prec.loc[df_prec.Month == 8]
df_prec_Sep = df_prec.loc[df_prec.Month == 9]
df_prec_Oct = df_prec.loc[df_prec.Month == 10]
df_prec_Nov = df_prec.loc[df_prec.Month == 11]
df_prec_Dec = df_prec.loc[df_prec.Month == 12]

# %%
df_prec_Jan.to_csv("df_prec_Jan.csv",index=False)
df_prec_Feb.to_csv("df_prec_Feb.csv",index=False)
df_prec_Mar.to_csv("df_prec_Mar.csv",index=False)
df_prec_Apr.to_csv("df_prec_Apr.csv",index=False)
df_prec_May.to_csv("df_prec_May.csv",index=False)
df_prec_Jun.to_csv("df_prec_Jun.csv",index=False)
df_prec_Jul.to_csv("df_prec_Jul.csv",index=False)
df_prec_Aug.to_csv("df_prec_Aug.csv",index=False)
df_prec_Sep.to_csv("df_prec_Sep.csv",index=False)
df_prec_Oct.to_csv("df_prec_Oct.csv",index=False)
df_prec_Nov.to_csv("df_prec_Nov.csv",index=False)
df_prec_Dec.to_csv("df_prec_Dec.csv",index=False)
